# %%
import tensorflow as tf
import numpy as np
import cv2
import matplotlib.pyplot as plt
from PIL import Image
from tensorflow.keras.preprocessing.image import load_img, img_to_array, array_to_img

# %matplotlib inline

# %%
model = tf.keras.models.load_model('intel_image_classifier_mobilenetv2.h5')

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 300, 300, 3)]     0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 150, 150, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 150, 150, 32)      128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 150, 150, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 150, 150, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 150, 150, 32)      128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 150, 150, 32)      0
# ...

# %%
img = load_img('test_images/test1.jpeg')

img_numpy_array = img_to_array(img)

image_resize = np.resize(img_numpy_array, (300, 300, 3))

image = np.expand_dims(image_resize, axis=0)

# %%
model.predict(image)
# Out:
# array([[3.7951095e-04, 1.7066703e-03, 9.1762263e-01, 2.2017343e-03,
#         7.7866890e-02, 2.2248873e-04]], dtype=float32)

# %%
pred = model.predict(image)

pred = np.argmax(pred)

pred
# Out:
# 2

# %%
labels = {0: 'buildings', 1: 'forest', 2: 'glacier', 3: 'mountain', 4: 'sea', 5: 'street'}

def predictor(pred, lables):
    for key, value in labels.items():
        if pred == key:
            print('The image is a ', value)

# %%
predictor(pred, labels)
# Out:
# The image is a  glacier
